# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv', index_col = 'Mon-Yr', parse_dates = True)

# %%
df.head()
# Out:
#               CA   Alameda San Francisco San Mateo Santa Clara
# Mon-Yr
# Jan-90  $194,952  $226,149      $287,499       NaN    $271,840
# Feb-90  $196,273  $219,306      $300,877       NaN    $273,100
# Mar-90  $194,856  $225,162      $290,151       NaN    $275,500
# Apr-90  $196,111  $229,333      $288,725       NaN    $274,660
# May-90  $195,281  $232,291      $282,626       NaN    $266,670

# %%
# df['CA'] = df['CA'].str.replace('$', '')
# df['CA'] = df['CA'].str.replace(',', '')
df['CA'] = pd.to_numeric(df['CA'])
# df['Alameda'] = df['Alameda'].str.replace('$', '')
# df['Alameda'] = df['Alameda'].str.replace(',', '')
df['Alameda'] = pd.to_numeric(df['Alameda'])
# df['San Francisco'] = df['San Francisco'].str.replace('$', '')
# df['San Francisco'] = df['San Francisco'].str.replace(',', '')
df['San Francisco'] = pd.to_numeric(df['San Francisco'])
# df['San Mateo'] = df['San Mateo'].str.replace('$', '')
# df['San Mateo'] = df['San Mateo'].str.replace(',', '')
df['San Mateo'] = pd.to_numeric(df['San Mateo'])
# df['Santa Clara'] = df['Santa Clara'].str.replace('$', '')
# df['Santa Clara'] = df['Santa Clara'].str.replace(',', '')
df['Santa Clara'] = pd.to_numeric(df['Santa Clara'])
df.head()
# Out:
#             CA  Alameda  San Francisco  San Mateo  Santa Clara
# Mon-Yr
# Jan-90  194952   226149         287499        NaN       271840
# Feb-90  196273   219306         300877        NaN       273100
# Mar-90  194856   225162         290151        NaN       275500
# Apr-90  196111   229333         288725        NaN       274660
# May-90  195281   232291         282626        NaN       266670

# %%
df.plot()
plt.show()
